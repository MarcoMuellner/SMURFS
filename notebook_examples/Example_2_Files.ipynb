# %% [markdown]
# # Example 2: Using files
#
# Smurfs can also deal with ASCII files. Except for the conversion into magnitude and sigma clipping, no reduction is applied.

# %%
# %matplotlib notebook
import os
os.chdir("..")
from smurfs import Smurfs

# %%
s = Smurfs(file='tests/test_files/testFile.dat')
# Out:
#  Reading data from tests/test_files/testFile.dat ...
#  Total observation length: 224.57 days.
#  Extracted data from target!
#  Duty cycle for testFile: 75.89%

# %%
s.plot_lc()
# Out:
# <img src="data:image/png;base64,..." width="848">

# %%
s.plot_pdg()
# Out:
# <img src="data:image/png;base64,..." width="848">

# %%
s.run(snr=4,window_size=2,extend_frequencies=5) #Extend frequencies
# Out:
#  Periodogramm from 0.0 1 / d to 1063.83 1 / d
#  Starting frequency extraction.
#  Skip similar:  Deactivated
#  Chancel after 10 similar:  Activated
#  Window size: 2
#  Number of extended frequencies: 5
#  Nyquist frequency: 1063.83 1 / d
#  List of frequencies, amplitudes, phases, S/N
#  F0   0.00690+/-0.00014 1 / d   0.147+/-0.009 mag   0.77+/-0.06   9.780089335917742
#  F1   47.43969+/-0.00014 1 / d   0.146+/-0.009 mag   0.11+/-0.06   10.578482524751951
#  F2   0.00557+/-0.00024 1 / d   0.088+/-0.009 mag   0.70+/-0.10   6.379493057414082
#  F3   50.49263+/-0.00024 1 / d   0.086+/-0.009 mag   0.43+/-0.10   6.813087904454906
#  F4   9.75218+/-0.00030 1 / d   0.069+/-0.009 mag   0.44+/-0.12   5.447366475731131
#  F5   0.00557+/-0.00031 1 / d   0.068+/-0.009 mag   0.13+/-0.13   4.830042966270659
#  F6   0.00557+/-0.00022 1 / d   0.096+/-0.009 mag   0.60+/-0.09   6.8342802737730075
#  F7   58.6206+/-0.0004 1 / d   0.058+/-0.009 mag   0.98+/-0.15   4.833527245269219
# ...

# %%
s.result
# Out:
#                                                 f_obj           frequency  \
# 0   <smurfs._smurfs.frequency_finder.Frequency obj...   0.00749+/-0.00012
# 1   <smurfs._smurfs.frequency_finder.Frequency obj...  47.43969+/-0.00015
# 2   <smurfs._smurfs.frequency_finder.Frequency obj...   0.00557+/-0.00024
# 3   <smurfs._smurfs.frequency_finder.Frequency obj...  50.49263+/-0.00025
# 4   <smurfs._smurfs.frequency_finder.Frequency obj...   9.75218+/-0.00031
# 5   <smurfs._smurfs.frequency_finder.Frequency obj...   0.00557+/-0.00031
# 6   <smurfs._smurfs.frequency_finder.Frequency obj...   0.00557+/-0.00022
# 7   <smurfs._smurfs.frequency_finder.Frequency obj...    58.6206+/-0.0004
# 8   <smurfs._smurfs.frequency_finder.Frequency obj...    58.6197+/-0.0004
# 9   <smurfs._smurfs.frequency_finder.Frequency obj...  58.61925+/-0.00025
# 10  <smurfs._smurfs.frequency_finder.Frequency obj...  58.61881+/-0.00014
# 11  <smurfs._smurfs.frequency_finder.Frequency obj...    14.6785+/-0.0004
# ...

# %%
s.ff.res_lc.scatter()
# Out:
# <img src="data:image/png;base64,..." width="848">
